# %%
import pandas as pd

# %%
data_copy = pd.read_csv("train.csv")
data_copy.head(10)
# Out:
#    sl_no  gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1       0  67.00   Others  91.00   Others  Commerce     58.00
# 1      2       0  79.33  Central  78.33   Others   Science     77.48
# 2      3       0  65.00  Central  68.00  Central      Arts     64.00
# 3      4       0  56.00  Central  52.00  Central   Science     52.00
# 4      5       0  85.80  Central  73.60  Central  Commerce     73.30
# 5      6       0  55.00   Others  49.80   Others   Science     67.25
# 6      7       1  46.00   Others  49.20   Others  Commerce     79.00
# 7      8       0  82.00  Central  64.00  Central   Science     66.00
# 8      9       0  73.00  Central  79.00  Central  Commerce     72.00
# 9     10       0  58.00  Central  70.00  Central  Commerce     61.00
#
#     degree_t workex  etest_p specialisation  mba_p      status    salary
# 0   Sci&Tech     No    55.00         Mkt&HR  58.80      Placed  270000.0
# 1   Sci&Tech    Yes    86.50        Mkt&Fin  66.28      Placed  200000.0
# 2  Comm&Mgmt     No    75.00        Mkt&Fin  57.80      Placed  250000.0
# 3   Sci&Tech     No    66.00         Mkt&HR  59.43  Not Placed       NaN
# 4  Comm&Mgmt     No    96.80        Mkt&Fin  55.50      Placed  425000.0
# 5   Sci&Tech    Yes    55.00        Mkt&Fin  51.58  Not Placed       NaN
# 6  Comm&Mgmt     No    74.28        Mkt&Fin  53.29  Not Placed       NaN
# 7   Sci&Tech    Yes    67.00        Mkt&Fin  62.14      Placed  252000.0
# 8  Comm&Mgmt     No    91.34        Mkt&Fin  61.29      Placed  231000.0
# 9  Comm&Mgmt     No    54.00        Mkt&Fin  52.21  Not Placed       NaN

# %%
change_columns = {'ssc_p' : "secondary_percent" ,'ssc_b' : "secondary_branch" ,
           'hsc_p' : "highschool_percent" ,'hsc_b' : "high_school_branch" ,
           'degree_p' : "degree_percent" ,'degree_t' : "degree_type" ,
          'mba_p' : 'mba_percent' ,'workex' : 'work_xp',
                 'etest_p' : "employment_test_percent"}

data_copy.rename(columns = change_columns , inplace = True)
data_copy
# Out:
#      sl_no  gender  secondary_percent secondary_branch  highschool_percent  \
# 0        1       0              67.00           Others               91.00
# 1        2       0              79.33          Central               78.33
# 2        3       0              65.00          Central               68.00
# 3        4       0              56.00          Central               52.00
# 4        5       0              85.80          Central               73.60
# ..     ...     ...                ...              ...                 ...
# 210    211       0              80.60           Others               82.00
# 211    212       0              58.00           Others               60.00
# 212    213       0              67.00           Others               67.00
# 213    214       1              74.00           Others               66.00
# 214    215       0              62.00          Central               58.00
#
#     high_school_branch     hsc_s  degree_percent degree_type work_xp  \
# 0               Others  Commerce           58.00    Sci&Tech      No
# 1               Others   Science           77.48    Sci&Tech     Yes
# 2              Central      Arts           64.00   Comm&Mgmt      No
# 3              Central   Science           52.00    Sci&Tech      No
# 4              Central  Commerce           73.30   Comm&Mgmt      No
# ..                 ...       ...             ...         ...     ...
# 210             Others  Commerce           77.60   Comm&Mgmt      No
# 211             Others   Science           72.00    Sci&Tech      No
# 212             Others  Commerce           73.00   Comm&Mgmt     Yes
# 213             Others  Commerce           58.00   Comm&Mgmt      No
# 214             Others   Science           53.00   Comm&Mgmt      No
#
#      employment_test_percent specialisation  mba_percent      status    salary
# 0                       55.0         Mkt&HR        58.80      Placed  270000.0
# 1                       86.5        Mkt&Fin        66.28      Placed  200000.0
# 2                       75.0        Mkt&Fin        57.80      Placed  250000.0
# 3                       66.0         Mkt&HR        59.43  Not Placed       NaN
# 4                       96.8        Mkt&Fin        55.50      Placed  425000.0
# ..                       ...            ...          ...         ...       ...
# 210                     91.0        Mkt&Fin        74.49      Placed  400000.0
# 211                     74.0        Mkt&Fin        53.62      Placed  275000.0
# 212                     59.0        Mkt&Fin        69.72      Placed  295000.0
# 213                     70.0         Mkt&HR        60.23      Placed  204000.0
# 214                     89.0         Mkt&HR        60.22  Not Placed       NaN
#
# [215 rows x 15 columns]

# %%
data_copy = data_copy.drop(['sl_no' , 'gender' , 'salary'],axis = 1)
data_copy
# Out:
#      secondary_percent secondary_branch  highschool_percent  \
# 0                67.00           Others               91.00
# 1                79.33          Central               78.33
# 2                65.00          Central               68.00
# 3                56.00          Central               52.00
# 4                85.80          Central               73.60
# ..                 ...              ...                 ...
# 210              80.60           Others               82.00
# 211              58.00           Others               60.00
# 212              67.00           Others               67.00
# 213              74.00           Others               66.00
# 214              62.00          Central               58.00
#
#     high_school_branch     hsc_s  degree_percent degree_type work_xp  \
# 0               Others  Commerce           58.00    Sci&Tech      No
# 1               Others   Science           77.48    Sci&Tech     Yes
# 2              Central      Arts           64.00   Comm&Mgmt      No
# 3              Central   Science           52.00    Sci&Tech      No
# 4              Central  Commerce           73.30   Comm&Mgmt      No
# ..                 ...       ...             ...         ...     ...
# 210             Others  Commerce           77.60   Comm&Mgmt      No
# 211             Others   Science           72.00    Sci&Tech      No
# 212             Others  Commerce           73.00   Comm&Mgmt     Yes
# 213             Others  Commerce           58.00   Comm&Mgmt      No
# 214             Others   Science           53.00   Comm&Mgmt      No
#
#      employment_test_percent specialisation  mba_percent      status
# 0                       55.0         Mkt&HR        58.80      Placed
# 1                       86.5        Mkt&Fin        66.28      Placed
# 2                       75.0        Mkt&Fin        57.80      Placed
# 3                       66.0         Mkt&HR        59.43  Not Placed
# 4                       96.8        Mkt&Fin        55.50      Placed
# ..                       ...            ...          ...         ...
# 210                     91.0        Mkt&Fin        74.49      Placed
# 211                     74.0        Mkt&Fin        53.62      Placed
# 212                     59.0        Mkt&Fin        69.72      Placed
# 213                     70.0         Mkt&HR        60.23      Placed
# 214                     89.0         Mkt&HR        60.22  Not Placed
#
# [215 rows x 12 columns]

# %%
data_copy.to_csv("sample_dataset.csv")

# %%
data_copy["degree_type"].value_counts()
